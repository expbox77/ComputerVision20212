# %% [markdown]
# # 1.3.2 Arithmetic Operations on Images
#
# ### cv2.add(), cv2.addWeighted() etc.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
x = 250
y = 10
x + y

# %%
# unsigned 로 나타낸다. 0 - 255까지라서 오버플로 발생
# 이미지의 color값은 255까지를 기준으로 한다.

x = np.uint8([250])
y = np.uint8([10])

# %%
print(y)

# %%
x + y

# %%
# 이미지 연산에서는 255를 넘어가는 값을 모두 255로 취급한다.
cv2.add(x,y)

# %%
def nothing(x):
    pass

# %%
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')

# %%
# cv2.addWeighted(imgA, a, imgB, b, c)
# result = imgA * a + imgB * b + c
cv2.createTrackbar('w','dst', 0, 255, nothing)

Blend = w / 255

dst = cv2.addWeighted(img1, w, img2, 1 - w, 0)

# %%
# cv2.imshow('dst',dst)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# cv2.waitKey(1)

while(True):
    cv2.imshow('dst', dst)
    k = cv2.waitKey(1) & 0xFF
    
    if k == 27:
        break
        
        
    # Trackbar 포지션 잡아주기
    Blend = cv2.getTrackbarPos('Blend','dst')
        
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')

cv2.namedWindow('image')
cv2.createTrackbar('weight', 'image', 0, 255, nothing)

while(True):
    k = cv2.waitKey(1) & 0xFF
    
    if k == 27:
        break
    weight = cv2.getTrackbarPos('weight', 'image')
    dst = cv2.addWeighted(img1, weight/255, img2, 1-weight/255,0)
    cv2.imshow('image', dst)

cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
# Load two images
img1 = cv2.imread('cat.jpg')
img2 = cv2.imread('logo.png')

# %%
# def pltImage(img):
#     plt.imshow(img)
#     plt.xticks([]), plt.yticks([])
#     plt.show
    
def pltImage(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
    plt.show()

# %%
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
print(rows, cols, channels)
# Out:
# 794 600 3

# %%
# img2의 크기만큼 img1를 잘라낸걸 roi에 저장한다.
roi = img1[0:rows, 0:cols ]

# %%
pltImage(img1)

# %%
pltImage(roi)

# %%
# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

# %%
pltImage(img2)

# %%
pltImage(img2gray)

# %%
ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)

# %%
pltImage(mask)

# %%
mask_inv = cv2.bitwise_not(mask)

# %%
pltImage(mask_inv)

# %%
# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)

# %%
pltImage(img1_bg)

# %%
# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)

# %%
pltImage(img2_fg)

# %%
# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols] = dst

# %%
pltImage(img1)

# %%
cv2.imshow('res',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1
